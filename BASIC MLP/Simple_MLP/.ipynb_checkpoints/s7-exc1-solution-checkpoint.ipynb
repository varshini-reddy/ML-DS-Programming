# %%
# usual imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#import tensorflow 
import tensorflow as tf
# You can avoid the long names by using
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
# %matplotlib inline

# %%
# we set a random seed to ensure our results are reproducible 
seed = 399
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Multilayer Perceptron
# We're using a slightly altered version of heart data from the previous exercise to illustrate a concept. Notice how now a single sigmoid will not be able to do an acceptible job of classification.

# %%
altered_heart_data = pd.read_csv('data/altered_heart_data.csv')
x = altered_heart_data.MaxHR.values
y = altered_heart_data.AHD.values
plt.scatter(x, y, alpha=0.2)
plt.xlabel('MaxHR')
plt.ylabel('Heart Disease (AHD)');

# %% [markdown]
# Now we will use Keras to construct our MLP. You need only add the output layer.
# Each step is described in the comments. We will go into more detail on Keras in the 1st lab.

# %%
## First we instantiate a Keras model
MLP = models.Sequential(name='MLP')

## [Adding Layers]
# Next we add a hidden layer with 2 nodes and a sigmoid activation function
MLP.add(layers.Dense(2, activation='sigmoid', input_shape=(1,), name='hidden'))

# Now add the output layer
# Use the code above as an example. You only need to change the arguments
# Choose number of nodes and activation and name it 'output'
# (the input shape will be infered from the hidden layer's output shape)
MLP.add(layers.Dense(1,  activation='sigmoid', name='output'))

# [Compilation]
# here we set the loss to be minimized and a metric to monitor when fitting the MLP
MLP.compile(loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# This simple model benefits from setting some reasonable initial weights.
# During fitting these weights will be optimized.

# %%
# get original random weights
weights = MLP.get_weights()
# hidden layer
weights[0][0]=np.array([ 3.1,-3.2]) #weights 
weights[1]=np.array([-350.,402.]) # biases
# output layer 
weights[2]=np.array([[1.29],[1.11]]) # weights
weights[3] = np.array([-1.11])    # bias
# update weights
MLP.set_weights(weights)

# %% [markdown]
# You should always inspect your Keras model with the `summary()` method. Note the number of parameters in each layer:
#
# Hidden has 4 - it contains 2 nodes each with a weight and bias.
#
# Output has 3 - it has a weight for each node in the previous layer plus a bias term.

# %%
MLP.summary()
# Out:
# Model: "MLP"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden (Dense)               (None, 2)                 4
# _________________________________________________________________
# output (Dense)               (None, 1)                 3
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we fit (or 'train') the MLP on our data, updating the weights to minimize the loss we specified in the call to `compile()`. (There will be more details on how this update happens in future lectures).
#
# One full training cycle on our data is called an 'epoch.' Usually multiple epochs are required before a model converges. Specify a number of epochs to train for.

# %%
MLP.fit(x, y, epochs=100);
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6690 - accuracy: 0.5655
# Epoch 2/100
# 5/5 [==============================] - 0s 840us/step - loss: 0.6676 - accuracy: 0.5655
# Epoch 3/100
# 5/5 [==============================] - 0s 963us/step - loss: 0.6573 - accuracy: 0.5655
# Epoch 4/100
# 5/5 [==============================] - 0s 896us/step - loss: 0.6558 - accuracy: 0.5655
# Epoch 5/100
# 5/5 [==============================] - 0s 822us/step - loss: 0.6480 - accuracy: 0.5655
# Epoch 6/100
# 5/5 [==============================] - 0s 935us/step - loss: 0.6417 - accuracy: 0.5655
# Epoch 7/100
# 5/5 [==============================] - 0s 900us/step - loss: 0.6353 - accuracy: 0.5655
# Epoch 8/100
# 5/5 [==============================] - 0s 916us/step - loss: 0.6302 - accuracy: 0.5655
# Epoch 9/100
# 5/5 [==============================] - 0s 883us/step - loss: 0.6283 - accuracy: 0.5655
# Epoch 10/100
# 5/5 [==============================] - 0s 801us/step - loss: 0.6299 - accuracy: 0.5655
# Epoch 11/100
# 5/5 [==============================] - 0s 807us/step - loss: 0.6220 - accuracy: 0.5655
# Epoch 12/100
# 5/5 [==============================] - 0s 802us/step - loss: 0.6277 - accuracy: 0.5655
# Epoch 13/100
# 5/5 [==============================] - 0s 820us/step - loss: 0.6161 - accuracy: 0.5655
# Epoch 14/100
# 5/5 [==============================] - 0s 798us/step - loss: 0.6169 - accuracy: 0.5655
# Epoch 15/100
# 5/5 [==============================] - 0s 840us/step - loss: 0.6202 - accuracy: 0.5655
# Epoch 16/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6170 - accuracy: 0.5655
# Epoch 17/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6133 - accuracy: 0.5655
# Epoch 18/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6103 - accuracy: 0.5655
# Epoch 19/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6091 - accuracy: 0.5655
# Epoch 20/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.6069
# Epoch 21/100
# 5/5 [==============================] - 0s 476us/step - loss: 0.6109 - accuracy: 0.8414
# Epoch 22/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6043 - accuracy: 0.8345
# Epoch 23/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6053 - accuracy: 0.8345
# Epoch 24/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6025 - accuracy: 0.8345
# Epoch 25/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.6018 - accuracy: 0.8345
# Epoch 26/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5964 - accuracy: 0.8345
# Epoch 27/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5950 - accuracy: 0.8345
# Epoch 28/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5953 - accuracy: 0.8414
# Epoch 29/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5918 - accuracy: 0.8414
# Epoch 30/100
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5907 - accuracy: 0.8414
# Epoch 31/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5918 - accuracy: 0.8414
# Epoch 32/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5891 - accuracy: 0.8414
# Epoch 33/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5898 - accuracy: 0.8414
# Epoch 34/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5885 - accuracy: 0.8414
# Epoch 35/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5904 - accuracy: 0.8483
# Epoch 36/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5853 - accuracy: 0.8483
# Epoch 37/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5879 - accuracy: 0.8483
# Epoch 38/100
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5851 - accuracy: 0.8483
# Epoch 39/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5775 - accuracy: 0.8483
# Epoch 40/100
# 5/5 [==============================] - 0s 859us/step - loss: 0.5783 - accuracy: 0.8483
# Epoch 41/100
# 5/5 [==============================] - 0s 769us/step - loss: 0.5756 - accuracy: 0.8483
# Epoch 42/100
# 5/5 [==============================] - 0s 735us/step - loss: 0.5755 - accuracy: 0.8483
# Epoch 43/100
# 5/5 [==============================] - 0s 739us/step - loss: 0.5787 - accuracy: 0.8483
# Epoch 44/100
# 5/5 [==============================] - 0s 988us/step - loss: 0.5766 - accuracy: 0.8483
# Epoch 45/100
# 5/5 [==============================] - 0s 762us/step - loss: 0.5736 - accuracy: 0.8483
# Epoch 46/100
# 5/5 [==============================] - 0s 763us/step - loss: 0.5694 - accuracy: 0.8483
# Epoch 47/100
# 5/5 [==============================] - 0s 765us/step - loss: 0.5696 - accuracy: 0.8483
# Epoch 48/100
# 5/5 [==============================] - 0s 751us/step - loss: 0.5723 - accuracy: 0.8483
# Epoch 49/100
# 5/5 [==============================] - 0s 777us/step - loss: 0.5641 - accuracy: 0.8483
# Epoch 50/100
# 5/5 [==============================] - 0s 790us/step - loss: 0.5677 - accuracy: 0.8483
# Epoch 51/100
# 5/5 [==============================] - 0s 817us/step - loss: 0.5686 - accuracy: 0.8483
# Epoch 52/100
# 5/5 [==============================] - 0s 813us/step - loss: 0.5675 - accuracy: 0.8483
# Epoch 53/100
# 5/5 [==============================] - 0s 807us/step - loss: 0.5613 - accuracy: 0.8552
# Epoch 54/100
# 5/5 [==============================] - 0s 809us/step - loss: 0.5656 - accuracy: 0.8621
# Epoch 55/100
# 5/5 [==============================] - 0s 810us/step - loss: 0.5593 - accuracy: 0.8552
# Epoch 56/100
# 5/5 [==============================] - 0s 844us/step - loss: 0.5628 - accuracy: 0.8621
# Epoch 57/100
# 5/5 [==============================] - 0s 811us/step - loss: 0.5608 - accuracy: 0.8621
# Epoch 58/100
# 5/5 [==============================] - 0s 817us/step - loss: 0.5580 - accuracy: 0.8621
# Epoch 59/100
# 5/5 [==============================] - 0s 822us/step - loss: 0.5641 - accuracy: 0.8621
# Epoch 60/100
# 5/5 [==============================] - 0s 818us/step - loss: 0.5576 - accuracy: 0.8621
# Epoch 61/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5581 - accuracy: 0.8621
# Epoch 62/100
# 5/5 [==============================] - 0s 816us/step - loss: 0.5615 - accuracy: 0.8621
# Epoch 63/100
# 5/5 [==============================] - 0s 807us/step - loss: 0.5574 - accuracy: 0.8690
# Epoch 64/100
# 5/5 [==============================] - 0s 829us/step - loss: 0.5545 - accuracy: 0.8621
# Epoch 65/100
# 5/5 [==============================] - 0s 819us/step - loss: 0.5569 - accuracy: 0.8690
# Epoch 66/100
# 5/5 [==============================] - 0s 845us/step - loss: 0.5549 - accuracy: 0.8690
# Epoch 67/100
# 5/5 [==============================] - 0s 813us/step - loss: 0.5548 - accuracy: 0.8621
# Epoch 68/100
# 5/5 [==============================] - 0s 810us/step - loss: 0.5545 - accuracy: 0.8690
# Epoch 69/100
# 5/5 [==============================] - 0s 804us/step - loss: 0.5527 - accuracy: 0.8621
# Epoch 70/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5544 - accuracy: 0.8621
# Epoch 71/100
# 5/5 [==============================] - 0s 827us/step - loss: 0.5520 - accuracy: 0.8621
# Epoch 72/100
# 5/5 [==============================] - 0s 808us/step - loss: 0.5553 - accuracy: 0.8621
# Epoch 73/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5536 - accuracy: 0.8621
# Epoch 74/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5497 - accuracy: 0.8621
# Epoch 75/100
# 5/5 [==============================] - 0s 837us/step - loss: 0.5509 - accuracy: 0.8621
# Epoch 76/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5505 - accuracy: 0.8690
# Epoch 77/100
# 5/5 [==============================] - 0s 816us/step - loss: 0.5483 - accuracy: 0.8690
# Epoch 78/100
# 5/5 [==============================] - 0s 825us/step - loss: 0.5556 - accuracy: 0.8621
# Epoch 79/100
# 5/5 [==============================] - 0s 836us/step - loss: 0.5441 - accuracy: 0.8690
# Epoch 80/100
# 5/5 [==============================] - 0s 827us/step - loss: 0.5491 - accuracy: 0.8621
# Epoch 81/100
# 5/5 [==============================] - 0s 827us/step - loss: 0.5471 - accuracy: 0.8621
# Epoch 82/100
# 5/5 [==============================] - 0s 809us/step - loss: 0.5499 - accuracy: 0.8621
# Epoch 83/100
# 5/5 [==============================] - 0s 823us/step - loss: 0.5445 - accuracy: 0.8690
# Epoch 84/100
# 5/5 [==============================] - 0s 815us/step - loss: 0.5432 - accuracy: 0.8690
# Epoch 85/100
# 5/5 [==============================] - 0s 839us/step - loss: 0.5502 - accuracy: 0.8690
# Epoch 86/100
# 5/5 [==============================] - 0s 815us/step - loss: 0.5422 - accuracy: 0.8690
# Epoch 87/100
# 5/5 [==============================] - 0s 834us/step - loss: 0.5492 - accuracy: 0.8690
# Epoch 88/100
# 5/5 [==============================] - 0s 858us/step - loss: 0.5476 - accuracy: 0.8690
# Epoch 89/100
# 5/5 [==============================] - 0s 833us/step - loss: 0.5489 - accuracy: 0.8690
# Epoch 90/100
# 5/5 [==============================] - 0s 834us/step - loss: 0.5489 - accuracy: 0.8621
# Epoch 91/100
# 5/5 [==============================] - 0s 828us/step - loss: 0.5388 - accuracy: 0.8621
# Epoch 92/100
# 5/5 [==============================] - 0s 898us/step - loss: 0.5436 - accuracy: 0.8621
# Epoch 93/100
# 5/5 [==============================] - 0s 829us/step - loss: 0.5449 - accuracy: 0.8690
# Epoch 94/100
# 5/5 [==============================] - 0s 818us/step - loss: 0.5438 - accuracy: 0.8690
# Epoch 95/100
# 5/5 [==============================] - 0s 847us/step - loss: 0.5479 - accuracy: 0.8621
# Epoch 96/100
# 5/5 [==============================] - 0s 815us/step - loss: 0.5392 - accuracy: 0.8690
# Epoch 97/100
# 5/5 [==============================] - 0s 832us/step - loss: 0.5422 - accuracy: 0.8690
# Epoch 98/100
# 5/5 [==============================] - 0s 813us/step - loss: 0.5472 - accuracy: 0.8690
# Epoch 99/100
# 5/5 [==============================] - 0s 820us/step - loss: 0.5384 - accuracy: 0.8690
# Epoch 100/100
# 5/5 [==============================] - 0s 820us/step - loss: 0.5429 - accuracy: 0.8690

# %% [markdown]
# We can plot the training history and observe that as the weights were updated our loss declined and the accuracy improved.

# %%
history = MLP.history.history
fig, ax = plt.subplots(1,2, figsize=(10,4))
ax[0].plot(history['loss'], c='r', label='loss')
ax[0].set_ylabel('crossentropy loss')
ax[1].plot(history['accuracy'], c='b')
ax[1].set_ylabel('accuracy')
for axis in ax:
    axis.set_xlabel('epoch')

# %% [markdown]
# Let's look at the individual outputs of the 2 nodes in the hidden layer.

# %%
# create xs for input to predict on
x_linspace = np.linspace(np.min(x), np.max(x), 500) 

# get output from the hidden layer nodes
hidden = models.Model(inputs=MLP.input, outputs=MLP.get_layer('hidden').output)
hidden_pred = hidden.predict(x_linspace)

h1_pred = hidden_pred[:,0]
h2_pred = hidden_pred[:,1]

# %%
#Plot output from h1 & h2
fig, ax = plt.subplots(1,1, figsize=(14,10))
ax.scatter(x, y, alpha=0.4, label='Altered Heart Data')
ax.plot(x_linspace, h1_pred, lw=4, alpha=0.6, label=r'$h_1 = \sigma(W_1x+\beta_1)$')
ax.plot(x_linspace, h2_pred, lw=4, alpha=0.6, label=r'$h_2 = \sigma(W_2x+\beta_2)$')

# Set title
ax.set_title('Hidden Layer Nodes', fontsize=24)

# Create labels (very important!)
ax.set_xlabel('$x$', fontsize=24) # Notice we make the labels big enough to read
ax.set_ylabel('$y$', fontsize=24)

ax.tick_params(labelsize=24) # Make the tick labels big enough to read

ax.legend(fontsize=24, loc='best'); # Create a legend and make it big enough to read

# %% [markdown]
# We can see that each node in the hidden layer indeed outputs a different sigmoid.
#
# Now let's look at how they are combined by the output layer.

# %%
# get output layer predictions
y_pred = MLP.predict(x_linspace)

# %%
# plot predictions
fig, ax = plt.subplots(1,1, figsize=(14,10))

ax.scatter(x, y, alpha=0.4, label=r'Altered Heart Data')
ax.plot(x_linspace, y_pred, lw=4, label=r'$y_{pred} = \sigma(W_3h_{1} + W_4h_{2}+\beta_{3})$')

# Create labels (very important!)
ax.set_xlabel('$x$', fontsize=24) # Notice we make the labels big enough to read
ax.set_ylabel('$y$', fontsize=24)

ax.tick_params(labelsize=24) # Make the tick labels big enough to read

ax.legend(fontsize=24, loc='best'); # Create a legend and make it big enough to read

# %% [markdown]
# Finally, let's compare the MLP's accuracy to a baseline that always predicts the majority class. Try and see if you can get over 80% accuracy (86%+ is possible). You may need to change the number of epochs above and rerun the notebook.

# %%
def accuracy(y_true, y_pred):
    assert y_true.shape[0] == y_pred.shape[0]
    return sum(y_true == (y_pred >= 0.5).astype(int))/len(y_true)

# %%
### edTest(test_performance) ###
final_pred = MLP.predict(x).flatten()

baseline_acc = accuracy(y, np.zeros(len(y))) # predictions are all zeros
MLP_acc = accuracy(y, final_pred)
print(f'Baseline Accuracy: {baseline_acc:.2%}')
print(f'MLP Accuracy: {MLP_acc:.2%}')
# Out:
# Baseline Accuracy: 65.52%
# MLP Accuracy: 86.90%
